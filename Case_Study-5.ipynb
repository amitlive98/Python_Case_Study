# %%
# •	Murders age group wise.

import matplotlib.pyplot as plt
import numpy as kp
import pandas as pd
import seaborn as sns

murder=pd.read_excel("Murder_Victim_Age.xlsx",sheet_name='Sheet1')
murder1=murder.iloc[:,[0,4,5,6,7,8,9,10]]
murder1.head()
#plt.imshow(murder)
# Out:
#                    Area_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0  Andaman & Nicobar Islands                   NaN             13
# 1             Andhra Pradesh                 282.0           2783
# 2          Arunachal Pradesh                   6.0             83
# 3                      Assam                  78.0           1356
# 4                      Bihar                 239.0           3643
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     1.0                  NaN                     NaN
# 1                    74.0                 73.0                   131.0
# 2                     0.0                  0.0                     0.0
# 3                    38.0                 21.0                   192.0
# 4                     2.0                  2.0                   196.0
#
#    Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# 0                     7.0                     5.0
# ...

# %%
murder2=murder1[['Area_Name','Victims_Above_50_Yrs','Victims_Upto_10_15_Yrs','Victims_Upto_10_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs']]
Murder3=murder2.groupby('Area_Name').sum()
Murder3["Area_Name"]=Murder3.index
Murder3.head()
#Murder3.plot(x=Murder3.Area_Name,y=['Victims_Above_50_Yrs','Victims_Upto_10_15_Yrs','Victims_Upto_10_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs'],kind='bar')
# Out:
#                            Victims_Above_50_Yrs  Victims_Upto_10_15_Yrs  \
# Area_Name
# Andaman & Nicobar Islands                  14.0                     3.0
# Andhra Pradesh                           3147.0                   290.0
# Arunachal Pradesh                          14.0                     0.0
# Assam                                     631.0                    48.0
# Bihar                                    1741.0                   144.0
#
#                            Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# Area_Name
# Andaman & Nicobar Islands                  6.0                     3.0
# Andhra Pradesh                           344.0                   422.0
# Arunachal Pradesh                          0.0                     0.0
# Assam                                     26.0                   223.0
# Bihar                                    136.0                   556.0
#
#                            Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# ...

# %%
#plt.rcParams['figure.figsize']=20,8
#sns.heatmap(data=murder2.dropna(axis=0))
#import plotly.plotly as py
Murder3.plot(x='Area_Name',y=['Victims_Above_50_Yrs','Victims_Upto_10_15_Yrs','Victims_Upto_10_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs'],kind='bar')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
# •	Offenders relation with rape victim
offenders = pd.read_csv('21_Offenders_known_to_the_victim.csv')
offenders.columns=['Area', 'Year','k_t_Victims','Neighbours','Known_persons','Parentsclose','Relatives']
offenders_new = offenders[['Area','k_t_Victims','Neighbours','Known_persons','Parentsclose','Relatives']]
offenders1=offenders_new.groupby('Area').sum()
offenders1.head()
sns.set_style('darkgrid')
sns.boxplot(data=offenders1)
